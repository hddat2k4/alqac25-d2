# %% [markdown]
# # Step 1: Chunk data

# %%
from utils import load_json, rechunk_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# WARNING:tensorflow:From c:\Users\datta\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
chunk_threshold = 500

# %%
law_data = load_json('data/alqac25_law.json')

# %%
rechunked_data = rechunk_data(data=law_data, threshold=chunk_threshold, output_file=f'data/private/alqac25_law_rechunked_{chunk_threshold}.json')
# Out:
# Rechunked 28 laws into 3628 chunks.
# ✅ Rechunked data saved to data/private/alqac25_law_rechunked_500.json

# %% [markdown]
# # Step 2: Embedding data

# %%
from utils import data_to_dict, embed_data, create_hybrid_collection, insert_data_with_vectors

# %%
data_for_embedding = data_to_dict(rechunked_data)
# Out:
# Converted data to dictionary with 3628 entries.

# %%
embedding_data = embed_data(data=data_for_embedding, output_file='data/private/embeddings.json')
# Out:
# CUDA available: True
# CUDA device count: 1
# Current CUDA device: 0
# CUDA device name: NVIDIA GeForce GTX 1650
# Using device: cuda:0
# Model device: cuda:0
# Processing batches:   0%|          | 0/227 [00:00<?, ?it/s]c:\Users\datta\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:371: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Processing batches: 100%|██████████| 227/227 [17:01<00:00,  4.50s/it]
# ✅ Embeddings saved to data/private/embeddings.json

# %%
name = f"alqac_law_collection_chunk_{chunk_threshold}"

# %%
create_hybrid_collection(name)
# Out:
# ✅ Created schema 'alqac_law_collection_chunk_500' successfully.

# %%
insert_data_with_vectors(name, embedding_data)
# Out:
# Total vectors in file: 3628
# Successfully inserted: 3628
# Failed to insert: 0
# Total processed: 3628

# %% [markdown]
# # Step 3: Retrieve

# %%
from utils import retrieve

# %%
retrieve(input_file="data/private/alqac25_private_test_Task_1.json",
        output_file="data/private/retrieval_candidates_rechunked_500_PRIVATE.json",
        name=name,
        mode="hybrid",
        top_k=12,
        alpha=0.8)
# Out:
# Initializing embedding model...
# Embedding model is ready.
# Successfully connected to Weaviate.
# Retrieving candidates (hybrid): 100%|██████████| 82/82 [00:36<00:00,  2.27question/s]
# ✅ Saved 82 retrieval results to file: data/private/retrieval_candidates_rechunked_500_PRIVATE.json
# Closed connection to Weaviate.

# %% [markdown]
# # Step 4: Rerank

# %%
from utils import rerank

# %%
rerank(candidate_file="data/private/retrieval_candidates_rechunked_500_PRIVATE.json",
       output_file=f"data/private/final_reranked_chunk_{chunk_threshold}_with_split_results_PRIVATE.json",
       threshold_mode="dynamic",
       threshold_value=1,
       batch_size=8)
# Out:
# Loading Cross-Encoder model for reranking...
# Using device: cuda
# Cross-Encoder model loaded successfully.
# Total questions to process: 82
# Processing questions:   0%|          | 0/82 [00:00<?, ?it/s]
# Epoch 1/82 - Question ID: private_test_alquac25_1
# Number of candidates: 12
# Processing questions:   1%|          | 1/82 [00:30<41:12, 30.53s/it]
# Reranking completed in 30.340 seconds
# Top score: 0.9990, Lowest score: 0.0003
# Dynamic threshold: 0.9990
# Filtered articles: 1/12
#
# Epoch 2/82 - Question ID: private_test_alquac25_2
# Number of candidates: 12
# Processing questions:   2%|▏         | 2/82 [00:32<18:25, 13.82s/it]
# Reranking completed in 2.120 seconds
# Top score: 0.5944, Lowest score: 0.0000
# Dynamic threshold: 0.5944
# Filtered articles: 1/12
#
# Epoch 3/82 - Question ID: private_test_alquac25_3
# Number of candidates: 12
# Processing questions:   4%|▎         | 3/82 [00:35<11:22,  8.63s/it]
# Reranking completed in 2.450 seconds
# Top score: 1.0000, Lowest score: 0.0012
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 4/82 - Question ID: private_test_alquac25_4
# Number of candidates: 12
# Processing questions:   5%|▍         | 4/82 [00:38<08:24,  6.47s/it]
# Reranking completed in 3.135 seconds
# Top score: 0.9945, Lowest score: 0.0000
# Dynamic threshold: 0.9945
# Filtered articles: 1/12
#
# Epoch 5/82 - Question ID: private_test_alquac25_5
# Number of candidates: 12
# Processing questions:   6%|▌         | 5/82 [00:41<06:48,  5.30s/it]
# Reranking completed in 3.229 seconds
# Top score: 0.9998, Lowest score: 0.0000
# Dynamic threshold: 0.9998
# Filtered articles: 1/12
#
# Epoch 6/82 - Question ID: private_test_alquac25_6
# Number of candidates: 12
# Processing questions:   7%|▋         | 6/82 [00:44<05:48,  4.58s/it]
# Reranking completed in 3.184 seconds
# Top score: 0.9694, Lowest score: 0.0000
# Dynamic threshold: 0.9694
# Filtered articles: 1/12
#
# Epoch 7/82 - Question ID: private_test_alquac25_7
# Number of candidates: 12
# Processing questions:   9%|▊         | 7/82 [00:49<05:49,  4.66s/it]
# Reranking completed in 4.819 seconds
# Top score: 0.7913, Lowest score: 0.0000
# Dynamic threshold: 0.7913
# Filtered articles: 1/12
#
# Epoch 8/82 - Question ID: private_test_alquac25_8
# Number of candidates: 12
# Processing questions:  10%|▉         | 8/82 [00:51<04:53,  3.96s/it]
# Reranking completed in 2.449 seconds
# Top score: 0.7958, Lowest score: 0.0003
# Dynamic threshold: 0.7958
# Filtered articles: 1/12
#
# Epoch 9/82 - Question ID: private_test_alquac25_9
# Number of candidates: 12
# Processing questions:  11%|█         | 9/82 [00:53<03:55,  3.23s/it]
# Reranking completed in 1.622 seconds
# Top score: 0.0057, Lowest score: 0.0000
# Dynamic threshold: 0.0057
# Filtered articles: 1/12
#
# Epoch 10/82 - Question ID: private_test_alquac25_10
# Number of candidates: 12
# Processing questions:  12%|█▏        | 10/82 [00:56<03:35,  2.99s/it]
# Reranking completed in 2.451 seconds
# Top score: 0.7384, Lowest score: 0.0000
# Dynamic threshold: 0.7384
# Filtered articles: 1/12
#
# Epoch 11/82 - Question ID: private_test_alquac25_11
# Number of candidates: 12
# Processing questions:  13%|█▎        | 11/82 [00:57<03:01,  2.55s/it]
# Reranking completed in 1.547 seconds
# Top score: 0.9996, Lowest score: 0.0003
# Dynamic threshold: 0.9996
# Filtered articles: 1/12
#
# Epoch 12/82 - Question ID: private_test_alquac25_12
# Number of candidates: 12
# Processing questions:  15%|█▍        | 12/82 [00:59<02:50,  2.44s/it]
# Reranking completed in 2.178 seconds
# Top score: 0.9993, Lowest score: 0.0001
# Dynamic threshold: 0.9993
# Filtered articles: 1/12
#
# Epoch 13/82 - Question ID: private_test_alquac25_13
# Number of candidates: 12
# Processing questions:  16%|█▌        | 13/82 [01:02<02:48,  2.45s/it]
# Reranking completed in 2.469 seconds
# Top score: 0.9796, Lowest score: 0.0000
# Dynamic threshold: 0.9796
# Filtered articles: 1/12
#
# Epoch 14/82 - Question ID: private_test_alquac25_14
# Number of candidates: 12
# Processing questions:  17%|█▋        | 14/82 [01:04<02:38,  2.33s/it]
# Reranking completed in 2.048 seconds
# Top score: 0.3201, Lowest score: 0.0002
# Dynamic threshold: 0.3201
# Filtered articles: 1/12
#
# Epoch 15/82 - Question ID: private_test_alquac25_15
# Number of candidates: 12
# Processing questions:  18%|█▊        | 15/82 [01:06<02:28,  2.22s/it]
# Reranking completed in 1.972 seconds
# Top score: 0.0066, Lowest score: 0.0000
# Dynamic threshold: 0.0066
# Filtered articles: 1/12
#
# Epoch 16/82 - Question ID: private_test_alquac25_16
# Number of candidates: 12
# Processing questions:  20%|█▉        | 16/82 [01:08<02:19,  2.11s/it]
# Reranking completed in 1.862 seconds
# Top score: 0.9999, Lowest score: 0.0000
# Dynamic threshold: 0.9999
# Filtered articles: 1/12
#
# Epoch 17/82 - Question ID: private_test_alquac25_17
# Number of candidates: 12
# Processing questions:  21%|██        | 17/82 [01:11<02:33,  2.37s/it]
# Reranking completed in 2.953 seconds
# Top score: 0.9785, Lowest score: 0.0002
# Dynamic threshold: 0.9785
# Filtered articles: 1/12
#
# Epoch 18/82 - Question ID: private_test_alquac25_18
# Number of candidates: 12
# Processing questions:  22%|██▏       | 18/82 [01:13<02:38,  2.47s/it]
# Reranking completed in 2.704 seconds
# Top score: 0.9998, Lowest score: 0.0000
# Dynamic threshold: 0.9998
# Filtered articles: 1/12
#
# Epoch 19/82 - Question ID: private_test_alquac25_19
# Number of candidates: 12
# Processing questions:  23%|██▎       | 19/82 [01:56<15:14, 14.51s/it]
# Reranking completed in 42.504 seconds
# Top score: 0.9998, Lowest score: 0.0066
# Dynamic threshold: 0.9998
# Filtered articles: 1/12
#
# Epoch 20/82 - Question ID: private_test_alquac25_20
# Number of candidates: 12
# Processing questions:  24%|██▍       | 20/82 [02:05<13:13, 12.79s/it]
# Reranking completed in 8.758 seconds
# Top score: 1.0000, Lowest score: 0.0001
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 21/82 - Question ID: private_test_alquac25_21
# Number of candidates: 12
# Processing questions:  26%|██▌       | 21/82 [02:08<10:05,  9.93s/it]
# Reranking completed in 3.245 seconds
# Top score: 0.9994, Lowest score: 0.0035
# Dynamic threshold: 0.9994
# Filtered articles: 1/12
#
# Epoch 22/82 - Question ID: private_test_alquac25_22
# Number of candidates: 12
# Processing questions:  27%|██▋       | 22/82 [02:16<09:30,  9.51s/it]
# Reranking completed in 8.513 seconds
# Top score: 0.9994, Lowest score: 0.0000
# Dynamic threshold: 0.9994
# Filtered articles: 1/12
#
# Epoch 23/82 - Question ID: private_test_alquac25_23
# Number of candidates: 12
# Processing questions:  28%|██▊       | 23/82 [02:59<19:13, 19.55s/it]
# Reranking completed in 42.893 seconds
# Top score: 0.9974, Lowest score: 0.0005
# Dynamic threshold: 0.9974
# Filtered articles: 1/12
#
# Epoch 24/82 - Question ID: private_test_alquac25_24
# Number of candidates: 12
# Processing questions:  29%|██▉       | 24/82 [03:02<13:54, 14.39s/it]
# Reranking completed in 2.342 seconds
# Top score: 0.9997, Lowest score: 0.0027
# Dynamic threshold: 0.9997
# Filtered articles: 1/12
#
# Epoch 25/82 - Question ID: private_test_alquac25_25
# Number of candidates: 12
# Processing questions:  30%|███       | 25/82 [03:04<10:17, 10.83s/it]
# Reranking completed in 2.500 seconds
# Top score: 0.9998, Lowest score: 0.0001
# Dynamic threshold: 0.9998
# Filtered articles: 1/12
#
# Epoch 26/82 - Question ID: private_test_alquac25_26
# Number of candidates: 12
# Processing questions:  32%|███▏      | 26/82 [03:07<07:54,  8.48s/it]
# Reranking completed in 3.000 seconds
# Top score: 0.7456, Lowest score: 0.0008
# Dynamic threshold: 0.7456
# Filtered articles: 1/12
#
# Epoch 27/82 - Question ID: private_test_alquac25_27
# Number of candidates: 12
# Processing questions:  33%|███▎      | 27/82 [03:09<06:01,  6.57s/it]
# Reranking completed in 2.100 seconds
# Top score: 0.9723, Lowest score: 0.0003
# Dynamic threshold: 0.9723
# Filtered articles: 1/12
#
# Epoch 28/82 - Question ID: private_test_alquac25_28
# Number of candidates: 12
# Processing questions:  34%|███▍      | 28/82 [03:12<04:43,  5.26s/it]
# Reranking completed in 2.197 seconds
# Top score: 0.9985, Lowest score: 0.0003
# Dynamic threshold: 0.9985
# Filtered articles: 1/12
#
# Epoch 29/82 - Question ID: private_test_alquac25_29
# Number of candidates: 12
# Processing questions:  35%|███▌      | 29/82 [03:14<03:53,  4.40s/it]
# Reranking completed in 2.399 seconds
# Top score: 0.9999, Lowest score: 0.0017
# Dynamic threshold: 0.9999
# Filtered articles: 1/12
#
# Epoch 30/82 - Question ID: private_test_alquac25_30
# Number of candidates: 12
# Processing questions:  37%|███▋      | 30/82 [03:16<03:12,  3.71s/it]
# Reranking completed in 2.085 seconds
# Top score: 0.9997, Lowest score: 0.0002
# Dynamic threshold: 0.9997
# Filtered articles: 1/12
#
# Epoch 31/82 - Question ID: private_test_alquac25_31
# Number of candidates: 12
# Processing questions:  38%|███▊      | 31/82 [03:19<02:49,  3.33s/it]
# Reranking completed in 2.448 seconds
# Top score: 1.0000, Lowest score: 0.0003
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 32/82 - Question ID: private_test_alquac25_32
# Number of candidates: 12
# Processing questions:  39%|███▉      | 32/82 [03:23<03:07,  3.76s/it]
# Reranking completed in 4.752 seconds
# Top score: 0.9934, Lowest score: 0.0001
# Dynamic threshold: 0.9934
# Filtered articles: 1/12
#
# Epoch 33/82 - Question ID: private_test_alquac25_33
# Number of candidates: 12
# Processing questions:  40%|████      | 33/82 [03:26<02:52,  3.52s/it]
# Reranking completed in 2.952 seconds
# Top score: 0.8869, Lowest score: 0.0001
# Dynamic threshold: 0.8869
# Filtered articles: 1/12
#
# Epoch 34/82 - Question ID: private_test_alquac25_34
# Number of candidates: 12
# Processing questions:  41%|████▏     | 34/82 [03:32<03:16,  4.10s/it]
# Reranking completed in 5.454 seconds
# Top score: 1.0000, Lowest score: 0.0019
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 35/82 - Question ID: private_test_alquac25_35
# Number of candidates: 12
# Processing questions:  43%|████▎     | 35/82 [03:37<03:34,  4.56s/it]
# Reranking completed in 5.611 seconds
# Top score: 1.0000, Lowest score: 0.0000
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 36/82 - Question ID: private_test_alquac25_36
# Number of candidates: 12
# Processing questions:  44%|████▍     | 36/82 [03:41<03:11,  4.16s/it]
# Reranking completed in 3.216 seconds
# Top score: 0.9800, Lowest score: 0.0001
# Dynamic threshold: 0.9800
# Filtered articles: 1/12
#
# Epoch 37/82 - Question ID: private_test_alquac25_37
# Number of candidates: 12
# Processing questions:  45%|████▌     | 37/82 [03:47<03:36,  4.81s/it]
# Reranking completed in 6.320 seconds
# Top score: 0.9931, Lowest score: 0.0002
# Dynamic threshold: 0.9931
# Filtered articles: 1/12
#
# Epoch 38/82 - Question ID: private_test_alquac25_38
# Number of candidates: 12
# Processing questions:  46%|████▋     | 38/82 [03:52<03:33,  4.85s/it]
# Reranking completed in 4.929 seconds
# Top score: 0.0425, Lowest score: 0.0000
# Dynamic threshold: 0.0425
# Filtered articles: 1/12
#
# Epoch 39/82 - Question ID: private_test_alquac25_39
# Number of candidates: 12
# Processing questions:  48%|████▊     | 39/82 [03:56<03:14,  4.52s/it]
# Reranking completed in 3.753 seconds
# Top score: 0.9307, Lowest score: 0.0002
# Dynamic threshold: 0.9307
# Filtered articles: 1/12
#
# Epoch 40/82 - Question ID: private_test_alquac25_40
# Number of candidates: 12
# Processing questions:  49%|████▉     | 40/82 [04:04<03:56,  5.63s/it]
# Reranking completed in 8.228 seconds
# Top score: 0.0272, Lowest score: 0.0000
# Dynamic threshold: 0.0272
# Filtered articles: 1/12
#
# Epoch 41/82 - Question ID: private_test_alquac25_41
# Number of candidates: 12
# Processing questions:  50%|█████     | 41/82 [04:11<04:11,  6.15s/it]
# Reranking completed in 7.330 seconds
# Top score: 0.6754, Lowest score: 0.0001
# Dynamic threshold: 0.6754
# Filtered articles: 1/12
#
# Epoch 42/82 - Question ID: private_test_alquac25_42
# Number of candidates: 12
# Processing questions:  51%|█████     | 42/82 [04:18<04:13,  6.35s/it]
# Reranking completed in 6.806 seconds
# Top score: 0.0103, Lowest score: 0.0000
# Dynamic threshold: 0.0103
# Filtered articles: 1/12
#
# Epoch 43/82 - Question ID: private_test_alquac25_43
# Number of candidates: 12
# Processing questions:  52%|█████▏    | 43/82 [04:22<03:39,  5.62s/it]
# Reranking completed in 3.926 seconds
# Top score: 0.7887, Lowest score: 0.0001
# Dynamic threshold: 0.7887
# Filtered articles: 1/12
#
# Epoch 44/82 - Question ID: private_test_alquac25_44
# Number of candidates: 12
# Processing questions:  54%|█████▎    | 44/82 [04:30<03:58,  6.27s/it]
# Reranking completed in 7.764 seconds
# Top score: 0.9003, Lowest score: 0.0001
# Dynamic threshold: 0.9003
# Filtered articles: 1/12
#
# Epoch 45/82 - Question ID: private_test_alquac25_45
# Number of candidates: 12
# Processing questions:  55%|█████▍    | 45/82 [04:34<03:33,  5.77s/it]
# Reranking completed in 4.622 seconds
# Top score: 0.0211, Lowest score: 0.0000
# Dynamic threshold: 0.0211
# Filtered articles: 1/12
#
# Epoch 46/82 - Question ID: private_test_alquac25_46
# Number of candidates: 12
# Processing questions:  56%|█████▌    | 46/82 [04:37<02:50,  4.73s/it]
# Reranking completed in 2.297 seconds
# Top score: 0.5391, Lowest score: 0.0005
# Dynamic threshold: 0.5391
# Filtered articles: 1/12
#
# Epoch 47/82 - Question ID: private_test_alquac25_47
# Number of candidates: 12
# Processing questions:  57%|█████▋    | 47/82 [04:39<02:16,  3.90s/it]
# Reranking completed in 1.954 seconds
# Top score: 0.9996, Lowest score: 0.0000
# Dynamic threshold: 0.9996
# Filtered articles: 1/12
#
# Epoch 48/82 - Question ID: private_test_alquac25_48
# Number of candidates: 12
# Processing questions:  59%|█████▊    | 48/82 [04:41<02:00,  3.53s/it]
# Reranking completed in 2.670 seconds
# Top score: 0.0543, Lowest score: 0.0000
# Dynamic threshold: 0.0543
# Filtered articles: 1/12
#
# Epoch 49/82 - Question ID: private_test_alquac25_49
# Number of candidates: 12
# Processing questions:  60%|█████▉    | 49/82 [04:44<01:47,  3.26s/it]
# Reranking completed in 2.605 seconds
# Top score: 0.9919, Lowest score: 0.0000
# Dynamic threshold: 0.9919
# Filtered articles: 1/12
#
# Epoch 50/82 - Question ID: private_test_alquac25_50
# Number of candidates: 12
# Processing questions:  61%|██████    | 50/82 [04:47<01:43,  3.22s/it]
# Reranking completed in 3.140 seconds
# Top score: 0.9969, Lowest score: 0.0000
# Dynamic threshold: 0.9969
# Filtered articles: 1/12
#
# Epoch 51/82 - Question ID: private_test_alquac25_51
# Number of candidates: 12
# Processing questions:  62%|██████▏   | 51/82 [04:49<01:28,  2.86s/it]
# Reranking completed in 2.007 seconds
# Top score: 0.8992, Lowest score: 0.0001
# Dynamic threshold: 0.8992
# Filtered articles: 1/12
#
# Epoch 52/82 - Question ID: private_test_alquac25_52
# Number of candidates: 12
# Processing questions:  63%|██████▎   | 52/82 [04:51<01:22,  2.75s/it]
# Reranking completed in 2.494 seconds
# Top score: 0.9993, Lowest score: 0.0501
# Dynamic threshold: 0.9993
# Filtered articles: 1/12
#
# Epoch 53/82 - Question ID: private_test_alquac25_53
# Number of candidates: 12
# Processing questions:  65%|██████▍   | 53/82 [04:54<01:17,  2.68s/it]
# Reranking completed in 2.502 seconds
# Top score: 1.0000, Lowest score: 0.0007
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 54/82 - Question ID: private_test_alquac25_54
# Number of candidates: 12
# Processing questions:  66%|██████▌   | 54/82 [04:56<01:06,  2.36s/it]
# Reranking completed in 1.628 seconds
# Top score: 0.9987, Lowest score: 0.0008
# Dynamic threshold: 0.9987
# Filtered articles: 1/12
#
# Epoch 55/82 - Question ID: private_test_alquac25_55
# Number of candidates: 12
# Processing questions:  67%|██████▋   | 55/82 [04:58<01:05,  2.42s/it]
# Reranking completed in 2.543 seconds
# Top score: 1.0000, Lowest score: 0.0039
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 56/82 - Question ID: private_test_alquac25_56
# Number of candidates: 12
# Processing questions:  68%|██████▊   | 56/82 [05:04<01:33,  3.59s/it]
# Reranking completed in 6.299 seconds
# Top score: 0.9289, Lowest score: 0.0004
# Dynamic threshold: 0.9289
# Filtered articles: 1/12
#
# Epoch 57/82 - Question ID: private_test_alquac25_57
# Number of candidates: 12
# Processing questions:  70%|██████▉   | 57/82 [06:01<08:05, 19.41s/it]
# Reranking completed in 56.234 seconds
# Top score: 0.2821, Lowest score: 0.0001
# Dynamic threshold: 0.2821
# Filtered articles: 1/12
#
# Epoch 58/82 - Question ID: private_test_alquac25_58
# Number of candidates: 12
# Processing questions:  71%|███████   | 58/82 [06:05<05:53, 14.71s/it]
# Reranking completed in 3.737 seconds
# Top score: 0.9978, Lowest score: 0.0030
# Dynamic threshold: 0.9978
# Filtered articles: 1/12
#
# Epoch 59/82 - Question ID: private_test_alquac25_59
# Number of candidates: 12
# Processing questions:  72%|███████▏  | 59/82 [06:52<09:24, 24.55s/it]
# Reranking completed in 47.443 seconds
# Top score: 0.9968, Lowest score: 0.0000
# Dynamic threshold: 0.9968
# Filtered articles: 1/12
#
# Epoch 60/82 - Question ID: private_test_alquac25_60
# Number of candidates: 12
# Processing questions:  73%|███████▎  | 60/82 [06:56<06:44, 18.39s/it]
# Reranking completed in 4.002 seconds
# Top score: 0.9984, Lowest score: 0.0010
# Dynamic threshold: 0.9984
# Filtered articles: 1/12
#
# Epoch 61/82 - Question ID: private_test_alquac25_61
# Number of candidates: 12
# Processing questions:  74%|███████▍  | 61/82 [07:00<04:53, 13.98s/it]
# Reranking completed in 3.673 seconds
# Top score: 0.9978, Lowest score: 0.0030
# Dynamic threshold: 0.9978
# Filtered articles: 1/12
#
# Epoch 62/82 - Question ID: private_test_alquac25_62
# Number of candidates: 12
# Processing questions:  76%|███████▌  | 62/82 [07:05<03:48, 11.45s/it]
# Reranking completed in 5.529 seconds
# Top score: 1.0000, Lowest score: 0.0001
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 63/82 - Question ID: private_test_alquac25_63
# Number of candidates: 12
# Processing questions:  77%|███████▋  | 63/82 [07:08<02:44,  8.67s/it]
# Reranking completed in 2.190 seconds
# Top score: 1.0000, Lowest score: 0.0000
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 64/82 - Question ID: private_test_alquac25_64
# Number of candidates: 12
# Processing questions:  78%|███████▊  | 64/82 [07:13<02:19,  7.76s/it]
# Reranking completed in 5.611 seconds
# Top score: 0.0679, Lowest score: 0.0000
# Dynamic threshold: 0.0679
# Filtered articles: 1/12
#
# Epoch 65/82 - Question ID: private_test_alquac25_65
# Number of candidates: 12
# Processing questions:  79%|███████▉  | 65/82 [07:18<01:55,  6.80s/it]
# Reranking completed in 4.572 seconds
# Top score: 0.9982, Lowest score: 0.0065
# Dynamic threshold: 0.9982
# Filtered articles: 1/12
#
# Epoch 66/82 - Question ID: private_test_alquac25_66
# Number of candidates: 12
# Processing questions:  80%|████████  | 66/82 [07:22<01:37,  6.07s/it]
# Reranking completed in 4.359 seconds
# Top score: 1.0000, Lowest score: 0.0006
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 67/82 - Question ID: private_test_alquac25_67
# Number of candidates: 12
# Processing questions:  82%|████████▏ | 67/82 [07:28<01:30,  6.02s/it]
# Reranking completed in 5.879 seconds
# Top score: 1.0000, Lowest score: 0.0000
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 68/82 - Question ID: private_test_alquac25_68
# Number of candidates: 12
# Processing questions:  83%|████████▎ | 68/82 [07:31<01:11,  5.10s/it]
# Reranking completed in 2.971 seconds
# Top score: 0.8960, Lowest score: 0.0022
# Dynamic threshold: 0.8960
# Filtered articles: 1/12
#
# Epoch 69/82 - Question ID: private_test_alquac25_69
# Number of candidates: 12
# Processing questions:  84%|████████▍ | 69/82 [07:35<01:02,  4.81s/it]
# Reranking completed in 4.105 seconds
# Top score: 0.9771, Lowest score: 0.0105
# Dynamic threshold: 0.9771
# Filtered articles: 1/12
#
# Epoch 70/82 - Question ID: private_test_alquac25_70
# Number of candidates: 12
# Processing questions:  85%|████████▌ | 70/82 [07:39<00:54,  4.56s/it]
# Reranking completed in 3.982 seconds
# Top score: 0.9810, Lowest score: 0.0000
# Dynamic threshold: 0.9810
# Filtered articles: 1/12
#
# Epoch 71/82 - Question ID: private_test_alquac25_71
# Number of candidates: 12
# Processing questions:  87%|████████▋ | 71/82 [07:42<00:46,  4.20s/it]
# Reranking completed in 3.340 seconds
# Top score: 0.1128, Lowest score: 0.0004
# Dynamic threshold: 0.1128
# Filtered articles: 1/12
#
# Epoch 72/82 - Question ID: private_test_alquac25_72
# Number of candidates: 12
# Processing questions:  88%|████████▊ | 72/82 [07:46<00:40,  4.02s/it]
# Reranking completed in 3.598 seconds
# Top score: 0.9966, Lowest score: 0.0000
# Dynamic threshold: 0.9966
# Filtered articles: 1/12
#
# Epoch 73/82 - Question ID: private_test_alquac25_73
# Number of candidates: 12
# Processing questions:  89%|████████▉ | 73/82 [07:49<00:33,  3.77s/it]
# Reranking completed in 3.174 seconds
# Top score: 0.9966, Lowest score: 0.0001
# Dynamic threshold: 0.9966
# Filtered articles: 1/12
#
# Epoch 74/82 - Question ID: private_test_alquac25_74
# Number of candidates: 12
# Processing questions:  90%|█████████ | 74/82 [07:53<00:31,  3.90s/it]
# Reranking completed in 4.193 seconds
# Top score: 0.9999, Lowest score: 0.0004
# Dynamic threshold: 0.9999
# Filtered articles: 1/12
#
# Epoch 75/82 - Question ID: private_test_alquac25_75
# Number of candidates: 12
# Processing questions:  91%|█████████▏| 75/82 [07:56<00:25,  3.65s/it]
# Reranking completed in 3.069 seconds
# Top score: 1.0000, Lowest score: 0.0001
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 76/82 - Question ID: private_test_alquac25_76
# Number of candidates: 12
# Processing questions:  93%|█████████▎| 76/82 [08:01<00:22,  3.78s/it]
# Reranking completed in 4.078 seconds
# Top score: 0.0169, Lowest score: 0.0000
# Dynamic threshold: 0.0169
# Filtered articles: 1/12
#
# Epoch 77/82 - Question ID: private_test_alquac25_77
# Number of candidates: 12
# Processing questions:  94%|█████████▍| 77/82 [08:04<00:18,  3.72s/it]
# Reranking completed in 3.559 seconds
# Top score: 0.2621, Lowest score: 0.0001
# Dynamic threshold: 0.2621
# Filtered articles: 1/12
#
# Epoch 78/82 - Question ID: private_test_alquac25_78
# Number of candidates: 12
# Processing questions:  95%|█████████▌| 78/82 [08:06<00:12,  3.13s/it]
# Reranking completed in 1.747 seconds
# Top score: 1.0000, Lowest score: 0.0003
# Dynamic threshold: 1.0000
# Filtered articles: 1/12
#
# Epoch 79/82 - Question ID: private_test_alquac25_79
# Number of candidates: 12
# Processing questions:  96%|█████████▋| 79/82 [08:09<00:09,  3.11s/it]
# Reranking completed in 3.049 seconds
# Top score: 0.8785, Lowest score: 0.0000
# Dynamic threshold: 0.8785
# Filtered articles: 1/12
#
# Epoch 80/82 - Question ID: private_test_alquac25_80
# Number of candidates: 12
# Processing questions:  98%|█████████▊| 80/82 [08:12<00:05,  2.99s/it]
# Reranking completed in 2.711 seconds
# Top score: 0.9904, Lowest score: 0.0000
# Dynamic threshold: 0.9904
# Filtered articles: 1/12
#
# Epoch 81/82 - Question ID: private_test_alquac25_81
# Number of candidates: 12
# Processing questions:  99%|█████████▉| 81/82 [08:14<00:02,  2.70s/it]
# Reranking completed in 2.010 seconds
# Top score: 0.9547, Lowest score: 0.0000
# Dynamic threshold: 0.9547
# Filtered articles: 1/12
#
# Epoch 82/82 - Question ID: private_test_alquac25_82
# Number of candidates: 12
# Processing questions: 100%|██████████| 82/82 [08:19<00:00,  6.10s/it]
# Reranking completed in 5.669 seconds
# Top score: 0.3776, Lowest score: 0.0000
# Dynamic threshold: 0.3776
# Filtered articles: 1/12
#
# ✅ Final results saved to: data/private/final_reranked_chunk_500_with_split_results_PRIVATE.json
# Processed 82 questions total
# Total relevant articles: 82
# Average articles per question: 1.00
